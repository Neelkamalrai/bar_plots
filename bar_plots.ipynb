# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
list1 = [7,5,12,6,7,9,4,6,7,11]
list2 = [5,7,6,9,4,7,7,5,4,9]
label1 = ['car','bike','tempo','riksaw','train','plan','rocket','satelite','bullet','ninja']

fig , ax = plt.subplots(figsize=(7,5))
plt.subplots_adjust(wspace = 0.1 , hspace = 0.1)

ax.bar(label1 , height = list1,zorder = 2 , label = 'hello blue')
ax.grid(color = 'red' , alpha = 0.6 , zorder = 1)
ax.bar(label1 , height = list2 , zorder = 3 , color = 'red' , width = 0.9, label = 'list1')
plt.legend( shadow = True ,loc='best' , labelcolor = 'green' , title = 'Neel Kamal Rai', ncols = 2)

# %%
list5 = [1,3,5,7,9]
list6 = [2,4,6,8,10]
yaxis = [20,30,40,10,25]

fig , ax = plt.subplots(figsize = (8,6))
plt.subplots_adjust(wspace = 0.1 , hspace = 0.1)

ax.bar(list5 , height = yaxis , color = '#f70505' , label = 'alone')
ax.bar(list6 , height = yaxis , color = '#0509f7' , label = 'alone2')
plt.legend(shadow = True , title = 'Neel' ,title_fontsize = 14 , draggable = True, ncols = 2 , facecolor = '#faf7a2' , edgecolor = 'black', borderpad = 0.8 , labelspacing = 1 )
ax.plot(3, 31, "🦁", markersize=10, color="r")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-1f17199f9f0b> in <cell line: 11>()
#       9 ax.bar(list6 , height = yaxis , color = '#0509f7' , label = 'alone2')
#      10 plt.legend(shadow = True , title = 'Neel' ,title_fontsize = 14 , draggable = True, ncols = 2 , facecolor = '#faf7a2' , edgecolor = 'black', borderpad = 0.8 , labelspacing = 1 )
# ---> 11 ax.plot(3, 31, "🦁", markersize=10, color="r")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# ...

# %%
import pandas as pd
import numpy as np

# Define the categories and the number of rows
categories = ['Apple', 'Banana', 'Cherry', 'Date', 'Fig', 'Grape', 'Mango']
num_rows = 20

# Create the DataFrame
data = {
    'Fruit': np.random.choice(categories, num_rows),
    'Number': np.random.randint(1, 101, num_rows)
}

df = pd.DataFrame(data)

sns.barplot(data = df , x = df.Fruit , y = df.Number , zorder = 2)
# plt.grid( color = 'red', alpha = 0.5 , zorder = 1 ,linewidth =2 )
# Out:
# <Axes: xlabel='Fruit', ylabel='Number'>

# %%
import matplotlib.pyplot as plt

# Create bars
barWidth = 0.9
bars1 = [3, 3, 1]
bars2 = [4, 2, 3]
bars3 = [4, 6, 7, 10, 4, 4]
bars4 = bars1 + bars2 + bars3

# The X position of bars
r1 = [1,5,9]
r2 = [2,6,10]
r3 = [3,4,7,8,11,12]
r4 = r1 + r2 + r3

# Create barplot
plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='Alone')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='With Himself')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='With other genotype')
# Note: the barplot could be created easily. See the barplot section for other examples.

# Create legend
plt.legend()

# Text below each barplot with a rotation at 90°
plt.xticks([r + barWidth for r in range(len(r4))], ['DD', 'with himself', 'with DC', 'with Silur', 'DC', 'with himself', 'with DD', 'with Silur', 'Silur', 'with himself', 'with DD', 'with DC'], rotation=90)

# Create labels
label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']

# Text on the top of each bar
for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)

# Adjust the margins
plt.subplots_adjust(bottom= 0.2, top = 0.98)

# Show graphic
plt.show()
